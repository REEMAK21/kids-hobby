# %% [markdown]
# # Kids Hobby Prediction Dataset
#
# The goal of collecting the dataset:
# To predict children's hobbies.
#
# The source of the dataset:
# https://www.kaggle.com/datasets/abtabm/hobby-prediction-basic?select=Hobby_Data.csv
#
# General information about the dataset:
# The number attributes: 14 columns.
# The number of objects: 1602 row.
# The type of attributes: Categorical, Boolean, and Numerical data.
# The class’s names: Academics, arts, sports.

# %% [markdown]
# <table>
# <tr>
#     <th>Attrbute name</th>
#     <th>Description</th>
#     <th>Data type</th>
# </tr>
#
# <tr>
#     <td>Olympiad_Participation</td>
#     <td>Has your child participated in any Science/Maths Olympiad?</td>
#     <td>Boolean</td>
# </tr>
#
# <tr>
#     <td>Scholarship</td>
#     <td>Has he/she received any scholarship?</td>
#     <td>Boolean</td>
# </tr>
#     <tr>
#     <td>School</td>
#     <td>Love's going to school?</td>
#     <td>Boolean</td>
# </tr>
#     <tr>
#     <td>Fav_sub</td>
#     <td>What is his/her favorite subject?</td>
#     <td>Categorical</td>
# </tr>
#     <tr>
#     <td>Projects</td>
#     <td>Has done any projects under academics before?</td>
#     <td>Boolean</td>
# </tr>
#     <tr>
#     <td>Grasp_pow</td>
#     <td>His/Her Grasping power (1-6)</td>
#     <td>Numerical</td>
# </tr>
#     <tr>
#     <td>Time_sprt</td>
#     <td>How much time does he/she spend playing outdoor/indoor games?</td>
#     <td>Numerical</td>
# </tr>
#     <tr>
#     <td>Medals</td>
#     <td>Medals won in Sports?</td>
#     <td>Boolean</td>
# </tr>
#     <tr>
#     <td>Career_sprt</td>
#     <td>Want's to pursue his/her career in sports?</td>
#     <td>Boolean</td>
# </tr>
#     <tr>
#     <td>Act_sprt</td>
#     <td>Regular in his/her sports activities?</td>
#     <td>Boolean</td>
# </tr>
#     <tr>
#     <td>Fant_arts</td>
#     <td>Love creating fantasy paintings?</td>
#     <td>Boolean</td>
# </tr>
#     <tr>
#     <td>Won_arts</td>
#     <td>Won art competitions?</td>
#     <td>Categorical</td>
# </tr>
#     <tr>
#     <td>Time_art</td>
#     <td>Time utilized in Arts?</td>
#     <td>Numerical</td>
# </tr>
#     <tr>
#     <td>Predicted Hobby</td>
#     <td>predictions for the hobby that the kid would like</td>
#     <td>Categorical</td>
# </tr>
#
# </table>
